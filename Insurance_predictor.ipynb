# %%
import os
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import seed
from scipy.stats import norm
from scipy.stats import t
from sklearn.preprocessing import StandardScaler

from matplotlib import rcParams
sns.set(style="darkgrid")
sns.set_context("poster")

# %%
df=pd.read_csv("tic_2000_eval_data.csv")

# %%
df.describe()
# Out:
#            MOSTYPE    MAANTHUI      MGEMOMV     MGEMLEEF     MOSHOOFD  \
# count  4000.000000  4000.00000  4000.000000  4000.000000  4000.000000
# mean     24.253000     1.10600     2.675750     3.004000     5.787000
# std      13.022822     0.42108     0.767306     0.790025     2.899609
# min       1.000000     1.00000     1.000000     1.000000     1.000000
# 25%      10.000000     1.00000     2.000000     3.000000     3.000000
# 50%      30.000000     1.00000     3.000000     3.000000     7.000000
# 75%      35.000000     1.00000     3.000000     3.000000     8.000000
# max      41.000000    10.00000     6.000000     6.000000    10.000000
#
#             MGODRK       MGODPR       MGODOV       MGODGE       MRELGE  ...  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000  ...
# mean      0.706750     4.653250     1.021250     3.269500     6.197000  ...
# std       1.032241     1.729093     1.001274     1.618958     1.876585  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     4.000000     0.000000     2.000000     5.000000  ...
# 50%       0.000000     5.000000     1.000000     3.000000     6.000000  ...
# 75%       1.000000     6.000000     2.000000     4.000000     7.000000  ...
# max       9.000000     9.000000     5.000000     9.000000     9.000000  ...
#
#             ALEVEN     APERSONG      AGEZONG     AWAOREG       ABRAND  \
# count  4000.000000  4000.000000  4000.000000  4000.00000  4000.000000
# mean      0.084500     0.003500     0.010000     0.00375     0.579750
# std       0.394206     0.059065     0.099511     0.06113     0.560106
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%       0.000000     0.000000     0.000000     0.00000     0.000000
# 50%       0.000000     0.000000     0.000000     0.00000     1.000000
# 75%       0.000000     0.000000     0.000000     0.00000     1.000000
# max       5.000000     1.000000     1.000000     1.00000     6.000000
#
#            AZEILPL     APLEZIER       AFIETS      AINBOED     ABYSTAND
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.001500     0.003750     0.031000     0.009250     0.013250
# std       0.038706     0.072369     0.206276     0.095743     0.114358
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     2.000000     4.000000     1.000000     1.000000
#
# [8 rows x 85 columns]

# %%
df.MOSTYPE.shape
# Out:
# (4000,)

# %%
df.keys()
# Out:
# Index(['MOSTYPE', 'MAANTHUI', 'MGEMOMV', 'MGEMLEEF', 'MOSHOOFD', 'MGODRK',
#        'MGODPR', 'MGODOV', 'MGODGE', 'MRELGE', 'MRELSA', 'MRELOV', 'MFALLEEN',
#        'MFGEKIND', 'MFWEKIND', 'MOPLHOOG', 'MOPLMIDD', 'MOPLLAAG', 'MBERHOOG',
#        'MBERZELF', 'MBERBOER', 'MBERMIDD', 'MBERARBG', 'MBERARBO', 'MSKA',
#        'MSKB1', 'MSKB2', 'MSKC', 'MSKD', 'MHHUUR', 'MHKOOP', 'MAUT1', 'MAUT2',
#        'MAUT0', 'MZFONDS', 'MZPART', 'MINKM30', 'MINK3045', 'MINK4575',
#        'MINK7512', 'MINK123M', 'MINKGEM', 'MKOOPKLA', 'PWAPART', 'PWABEDR',
#        'PWALAND', 'PPERSAUT', 'PBESAUT', 'PMOTSCO', 'PVRAAUT', 'PAANHANG',
#        'PTRACTOR', 'PWERKT', 'PBROM', 'PLEVEN', 'PPERSONG', 'PGEZONG',
#        'PWAOREG', 'PBRAND', 'PZEILPL', 'PPLEZIER', 'PFIETS', 'PINBOED',
#        'PBYSTAND', 'AWAPART', 'AWABEDR', 'AWALAND', 'APERSAUT', 'ABESAUT',
#        'AMOTSCO', 'AVRAAUT', 'AAANHANG', 'ATRACTOR', 'AWERKT', 'ABROM',
#        'ALEVEN', 'APERSONG', 'AGEZONG', 'AWAOREG', 'ABRAND', 'AZEILPL',
#        'APLEZIER', 'AFIETS', 'AINBOED', 'ABYSTAND'],
#       dtype='object')

# %%
corr = df.corr()
fig = plt.figure(figsize=(50,40))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df.columns)
ax.set_yticklabels(df.columns)
plt.show()

# %%
#Drop highly correlated features to get better view of correlation.
# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.70)]

# Drop features 
df.drop(to_drop, axis=1, inplace=True)

# %%
corr = df.corr()
fig = plt.figure(figsize=(75,65))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df.columns)
ax.set_yticklabels(df.columns)
plt.show()

# %%
#Dropped variables
print(to_drop)
# Out:
# ['MOSHOOFD', 'MGODGE', 'MRELOV', 'MFALLEEN', 'MFWEKIND', 'MOPLLAAG', 'MSKA', 'MHKOOP', 'MAUT0', 'MZPART', 'AWAPART', 'AWABEDR', 'AWALAND', 'APERSAUT', 'ABESAUT', 'AMOTSCO', 'AVRAAUT', 'AAANHANG', 'ATRACTOR', 'AWERKT', 'ABROM', 'ALEVEN', 'APERSONG', 'AGEZONG', 'AWAOREG', 'ABRAND', 'AZEILPL', 'APLEZIER', 'AFIETS', 'AINBOED', 'ABYSTAND']

# %%
df.corr()
# Out:
#            MOSTYPE  MAANTHUI   MGEMOMV  MGEMLEEF    MGODRK    MGODPR  \
# MOSTYPE   1.000000 -0.042559  0.016170  0.021801 -0.216328  0.095448
# MAANTHUI -0.042559  1.000000 -0.025167  0.046082  0.018604 -0.040863
# MGEMOMV   0.016170 -0.025167  1.000000 -0.357985  0.003995  0.059609
# MGEMLEEF  0.021801  0.046082 -0.357985  1.000000 -0.039957  0.088884
# MGODRK   -0.216328  0.018604  0.003995 -0.039957  1.000000 -0.356667
# MGODPR    0.095448 -0.040863  0.059609  0.088884 -0.356667  1.000000
# MGODOV   -0.034510  0.031429 -0.120571  0.059956  0.025870 -0.319570
# MRELGE   -0.028429 -0.016306  0.525945 -0.085373 -0.010188  0.124403
# MRELSA   -0.023304 -0.016021 -0.182767 -0.272380  0.113373 -0.222052
# MFGEKIND -0.060574 -0.065573 -0.329498  0.226071  0.026351  0.013005
# MOPLHOOG -0.490406  0.009217  0.030642 -0.036640  0.248602 -0.107916
# MOPLMIDD -0.258515 -0.058181  0.040023 -0.215727  0.121672 -0.003006
# MBERHOOG -0.422378 -0.003361  0.040753  0.127544  0.232881 -0.021940
# MBERZELF -0.136250  0.023453  0.064105  0.020649  0.074493  0.034745
# MBERBOER  0.253761 -0.029754  0.098261  0.082975 -0.115351  0.121119
# PBYSTAND  0.005435  0.045905  0.070818 -0.004237  0.021393  0.011265
#
#            PINBOED  PBYSTAND
# MOSTYPE  -0.019746 -0.021531
# MAANTHUI  0.038290 -0.006136
# MGEMOMV  -0.007852  0.035099
# MGEMLEEF  0.005306 -0.017276
# MGODRK    0.044253 -0.010514
# MGODPR   -0.020063  0.031535
# MGODOV   -0.022074 -0.000390
# MRELGE   -0.002037  0.018892
# MRELSA   -0.016121 -0.022096
# MFGEKIND  0.001371 -0.017329
# MOPLHOOG  0.023661  0.011535
# MOPLMIDD  0.036147  0.028896
# MBERHOOG  0.048590  0.004376
# MBERZELF  0.002809 -0.006127
# MBERBOER -0.011866 -0.007860
# MBERMIDD -0.005908  0.025653
# MBERARBG -0.025025 -0.008909
# MBERARBO -0.017344 -0.032575
# MSKB1    -0.013132  0.024385
# MSKB2     0.008666  0.012355
# MSKC     -0.018144 -0.035522
# MSKD     -0.037713 -0.020832
# MHHUUR    0.000917 -0.031890
# MAUT1    -0.014580  0.001980
# MAUT2     0.016925  0.013649
# MZFONDS  -0.033476 -0.018650
# MINKM30  -0.028883  0.007276
# MINK3045 -0.010153 -0.010648
# MINK4575  0.047962  0.000346
# MINK7512 -0.004120 -0.005371
# MINK123M -0.003432 -0.003964
# MINKGEM   0.032785  0.003471
# MKOOPKLA  0.033829  0.040241
# PWAPART   0.057889  0.033421
# PWABEDR   0.017134  0.048701
# PWALAND  -0.012202  0.075070
# PPERSAUT  0.040862  0.075600
# PBESAUT  -0.008681  0.069011
# PMOTSCO  -0.010314  0.062744
# PVRAAUT  -0.002911 -0.003935
# PAANHANG  0.017113  0.083762
# PTRACTOR -0.012931  0.031516
# PWERKT   -0.003933  0.028693
# PBROM    -0.013569 -0.000274
# PLEVEN    0.044361  0.068228
# PPERSONG  0.024957  0.028332
# PGEZONG   0.010620  0.005435
# PWAOREG  -0.005055  0.045905
# PBRAND    0.055618  0.070818
# PZEILPL   0.121758 -0.004237
# PPLEZIER -0.004239  0.021393
# PFIETS    0.015334  0.011265
# PINBOED   1.000000  0.038544
# PBYSTAND  0.038544  1.000000
#
# [54 rows x 54 columns]

# %%
df.describe()
# Out:
#            MOSTYPE    MAANTHUI      MGEMOMV     MGEMLEEF       MGODRK  \
# count  4000.000000  4000.00000  4000.000000  4000.000000  4000.000000
# mean     24.253000     1.10600     2.675750     3.004000     0.706750
# std      13.022822     0.42108     0.767306     0.790025     1.032241
# min       1.000000     1.00000     1.000000     1.000000     0.000000
# 25%      10.000000     1.00000     2.000000     3.000000     0.000000
# 50%      30.000000     1.00000     3.000000     3.000000     0.000000
# 75%      35.000000     1.00000     3.000000     3.000000     1.000000
# max      41.000000    10.00000     6.000000     6.000000     9.000000
#
#             MGODPR       MGODOV       MRELGE       MRELSA     MFGEKIND  ...  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000  ...
# mean      4.653250     1.021250     6.197000     0.858000     3.247500  ...
# std       1.729093     1.001274     1.876585     0.956067     1.593386  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       4.000000     0.000000     5.000000     0.000000     2.000000  ...
# 50%       5.000000     1.000000     6.000000     1.000000     3.000000  ...
# 75%       6.000000     2.000000     7.000000     1.000000     4.000000  ...
# max       9.000000     5.000000     9.000000     7.000000     9.000000  ...
#
#             PLEVEN     PPERSONG      PGEZONG      PWAOREG       PBRAND  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.213250     0.008250     0.023750     0.023000     1.881000
# std       0.928434     0.153909     0.241248     0.375508     1.883939
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     2.000000
# 75%       0.000000     0.000000     0.000000     0.000000     4.000000
# max       7.000000     5.000000     3.000000     7.000000     8.000000
#
#            PZEILPL     PPLEZIER       PFIETS      PINBOED     PBYSTAND
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.002750     0.010000     0.025500     0.018250     0.042250
# std       0.072414     0.194704     0.157658     0.221199     0.378815
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       2.000000     5.000000     1.000000     6.000000     5.000000
#
# [8 rows x 54 columns]

# %%
# test classification dataset
from sklearn.datasets import make_classification
# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=5)
# summarize the dataset
print(X.shape, y.shape)
# Out:
# (1000, 20) (1000,)

# %%
# evaluate bagging algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import BaggingClassifier
# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=5)
# define the model
model = BaggingClassifier()
# evaluate the model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.864 (0.042)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 54 columns):
# MOSTYPE     4000 non-null int64
# MAANTHUI    4000 non-null int64
# MGEMOMV     4000 non-null int64
# MGEMLEEF    4000 non-null int64
# MGODRK      4000 non-null int64
# MGODPR      4000 non-null int64
# MGODOV      4000 non-null int64
# MRELGE      4000 non-null int64
# MRELSA      4000 non-null int64
# MFGEKIND    4000 non-null int64
# MOPLHOOG    4000 non-null int64
# MOPLMIDD    4000 non-null int64
# MBERHOOG    4000 non-null int64
# MBERZELF    4000 non-null int64
# MBERBOER    4000 non-null int64
# MBERMIDD    4000 non-null int64
# MBERARBG    4000 non-null int64
# MBERARBO    4000 non-null int64
# MSKB1       4000 non-null int64
# MSKB2       4000 non-null int64
# MSKC        4000 non-null int64
# MSKD        4000 non-null int64
# MHHUUR      4000 non-null int64
# MAUT1       4000 non-null int64
# MAUT2       4000 non-null int64
# MZFONDS     4000 non-null int64
# MINKM30     4000 non-null int64
# MINK3045    4000 non-null int64
# MINK4575    4000 non-null int64
# MINK7512    4000 non-null int64
# MINK123M    4000 non-null int64
# MINKGEM     4000 non-null int64
# MKOOPKLA    4000 non-null int64
# PWAPART     4000 non-null int64
# PWABEDR     4000 non-null int64
# PWALAND     4000 non-null int64
# PPERSAUT    4000 non-null int64
# PBESAUT     4000 non-null int64
# PMOTSCO     4000 non-null int64
# PVRAAUT     4000 non-null int64
# PAANHANG    4000 non-null int64
# PTRACTOR    4000 non-null int64
# PWERKT      4000 non-null int64
# PBROM       4000 non-null int64
# PLEVEN      4000 non-null int64
# PPERSONG    4000 non-null int64
# PGEZONG     4000 non-null int64
# PWAOREG     4000 non-null int64
# PBRAND      4000 non-null int64
# PZEILPL     4000 non-null int64
# PPLEZIER    4000 non-null int64
# PFIETS      4000 non-null int64
# PINBOED     4000 non-null int64
# PBYSTAND    4000 non-null int64
# dtypes: int64(54)
# memory usage: 1.6 MB
